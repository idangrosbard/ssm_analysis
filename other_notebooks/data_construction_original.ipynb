# %% [markdown]
# # Setup

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import src.models.minimal_mamba2 as minimal_mamba2
import src.models.minimal_mamba2_new as minimal_mamba2_new
from transformers import AutoTokenizer

torch.set_grad_enabled(False)

# %%
from src.consts import FILTERATIONS
from src.datasets.download_dataset import load_splitted_counter_fact
from tqdm import tqdm
from src.types import MODEL_ARCH

# %%
device = "cuda:1"
# model_name = "state-spaces/mamba2-1.3b"
model_name = "state-spaces/mamba2-130M"
seed = 0

# %%
# Uncomment below to set correct caching directories

# hf_dir = XXX
# tri_dir = YYY
# xdg_dir = ZZZ
# os.environ['HF_HOME'] = hf_dir
# os.environ['TRITON_CACHE_DIR'] = tri_dir
# os.environ['XDG_CACHE_HOME'] = xdg_dir

# %% [markdown]
# # Predict

# %%
original_data = pd.DataFrame(load_splitted_counter_fact(
    "all", align_to_known=False, filteration=FILTERATIONS.all_correct
))
original_data['true_prob'] = 0.0
original_data['max_prob'] = 0.0
original_data['hit'] = False
original_data['pred'] = ""

# %%
# tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neox-20b", cache_dir=hf_dir, use_fast=True)

# %%
tokenizer = AutoTokenizer.from_pretrained("EleutherAI/gpt-neox-20b")
tokenizer.pad_token = tokenizer.eos_token

# %%
from scripts.evaluate_model import generate_next_tokens
from src.logit_utils import logits_to_probs

model_arch = MODEL_ARCH.MINIMAL_MAMBA2
model = minimal_mamba2.Mamba2LMHeadModel.from_pretrained(model_name, device=device)
get_logits = lambda **kwargs: logits_to_probs(generate_next_tokens(
    model=model, input_ids=kwargs['input_ids'], num_tokens_to_generate=1, model_arch=model_arch
    )[1])

# %%
model = minimal_mamba2_new.Mamba2LMHeadModel.from_pretrained(model_name, device=device)

get_logits = lambda **kwargs: model.generate_single(
        input_ids=kwargs['input_ids'],
        max_new_length=kwargs['max_new_length'],
        temperature=kwargs['temperature'],
        top_k=kwargs['top_k'],
        top_p=kwargs['top_p'],
        eos_token_id=tokenizer.eos_token,
        attention=kwargs['attention'],
    )

# %%
torch.random.manual_seed(seed)
model.eval()
temperature = 1
top_k = 0
top_p = 1
attention = False

# %%
def forward_eval(temperature, top_k, top_p, batch_start, batch_end, attention, print_period=10000):
    prompts = list(original_data.loc[batch_start:batch_end-1, 'prompt'].values)
    true_word = list(original_data.loc[batch_start:batch_end-1, 'target_true'].values)
    true_token = tokenizer(true_word, return_tensors="pt", padding=True)
    true_id = true_token.input_ids.to(device='cpu')
    tokens = tokenizer(prompts, return_tensors="pt", padding=True)
    input_ids = tokens.input_ids.to(device=device)
    max_new_length = input_ids.shape[1] + 1
    out = get_logits(
        input_ids=input_ids,
        max_new_length=max_new_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        eos_token_id=tokenizer.eos_token,
        attention=attention,
    )
    next_token_probs = out[-1].detach().cpu().numpy()
    max_idx = np.argmax(next_token_probs, axis=1)
    row_idx = np.arange(next_token_probs.shape[0])
    preds = [tokenizer.decode([t]) for t in max_idx]
    original_data.loc[batch_start:batch_end-1, 'true_prob'] = next_token_probs[row_idx, true_id[:, 0]]
    original_data.loc[batch_start:batch_end-1, 'max_prob'] = next_token_probs[row_idx, max_idx]
    original_data.loc[batch_start:batch_end-1, 'hit'] = original_data.loc[batch_start:batch_end-1, 'true_prob'] == original_data.loc[batch_start:batch_end-1, 'max_prob']
    original_data.loc[batch_start:batch_end-1, 'pred'] = preds
    if (batch_start+1) % print_period == 0:
        print(f'Finished batch [{batch_start}:{batch_end-1}]')
    torch.cuda.empty_cache()

# %%
batch_size = 1
N = len(original_data)
batches = list(np.arange(0, N, batch_size)) + [N]

# %%
idx = original_data.pipe(lambda x: x[x['original_idx'] == 17689]).index.values[0]
forward_eval(temperature, top_k, top_p, batches[idx], batches[idx+1], attention)
original_data.iloc[idx:idx+1]
# Out:
#                    relation relation_prefix           relation_suffix  \
# 8  {} worked in the city of                  {} worked in the city of
#
#                                        prompt relation_id target_false_id  \
# 8  Pierre-Jean Mariette worked in the city of        P937          Q29364
#
#   target_true_id target_true target_false               subject  original_idx  \
# 8            Q90       Paris   Montgomery  Pierre-Jean Mariette         17689
#
#     split  true_prob  max_prob   hit    pred
# 8  train1   0.145603  0.145603  True   Paris

# %%
idx = original_data.pipe(lambda x: x[x['original_idx'] == 17689]).index.values[0]
forward_eval(temperature, top_k, top_p, batches[idx], batches[idx+1], attention)
original_data.iloc[idx:idx+1]
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 idx = original_data.pipe(lambda x: x[x['original_idx'] == 17689]).index.values[0]
# ----> 2 forward_eval(temperature, top_k, top_p, batches[idx], batches[idx+1], attention)
#       3 original_data.iloc[idx:idx+1]
#
# Cell In[11], line 19, in forward_eval(temperature, top_k, top_p, batch_start, batch_end, attention, print_period)
#       9 out = get_logits(
#      10     input_ids=input_ids,
#      11     max_new_length=max_new_length,
#    (...)
#      16     attention=attention,
#      17 )
#      18 next_token_probs = out[-1].detach().cpu().numpy()
# ---> 19 max_idx = np.argmax(next_token_probs, axis=1)
#      20 row_idx = np.arange(next_token_probs.shape[0])
#      21 preds = [tokenizer.decode([t]) for t in max_idx]
#
# File /home/yandex/DL20232024a/nirendy/repos/ADL_2/venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:1229, in argmax(a, axis, out, keepdims)
#    1142 """
#    1143 Returns the indices of the maximum values along an axis.
#    1144
#    (...)
#    1226 (2, 1, 4)
#    1227 """
#    1228 kwds = {'keepdims': keepdims} if keepdims is not np._NoValue else {}
# -> 1229 return _wrapfunc(a, 'argmax', axis=axis, out=out, **kwds)
#
# File /home/yandex/DL20232024a/nirendy/repos/ADL_2/venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
#      62     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      66     # Call _wrapit from within the except clause to ensure a potential
#      67     # exception has a traceback chain.
#      68     return _wrapit(obj, method, *args, **kwds)
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
original_data.iloc[idx:idx+1]
# Out:
#                    relation relation_prefix           relation_suffix  \
# 8  {} worked in the city of                  {} worked in the city of
#
#                                        prompt relation_id target_false_id  \
# 8  Pierre-Jean Mariette worked in the city of        P937          Q29364
#
#   target_true_id target_true target_false               subject  original_idx  \
# 8            Q90       Paris   Montgomery  Pierre-Jean Mariette         17689
#
#     split  true_prob   max_prob   hit    pred
# 8  train1  82.855637  82.855637  True   Paris

# %%
for i in tqdm(range(len(batches)-2)):
    forward_eval(temperature, top_k, top_p, batches[i], batches[i+1], attention)
# Out:
#   0%|          | 0/826 [00:00<?, ?it/s]
# 100%|██████████| 826/826 [06:55<00:00,  1.99it/s]

# %%
original_data.pipe(lambda df: df[~df['hit']])
# Out:
#                            relation relation_prefix  \
# 8          {} worked in the city of
# 186                  {}, created by
# 197              {} is a product of
# 251  {} belongs to the continent of
# 259                  {} is owned by
# 403       {} is a native speaker of
# 479       {} is a native speaker of
# 545              {} is a product of
# 597                {} is written in
# 633     {} holds a citizenship from
# 752          {} is headquartered in
# 775  {}, who has a citizenship from
# 799              {} is a product of
#
#                     relation_suffix  \
# 8          {} worked in the city of
# 186                  {}, created by
# 197              {} is a product of
# 251  {} belongs to the continent of
# 259                  {} is owned by
# 403       {} is a native speaker of
# 479       {} is a native speaker of
# 545              {} is a product of
# 597                {} is written in
# 633     {} holds a citizenship from
# 752          {} is headquartered in
# 775  {}, who has a citizenship from
# 799              {} is a product of
#
#                                                 prompt relation_id  \
# 8           Pierre-Jean Mariette worked in the city of        P937
# 186                Microsoft Office Mobile, created by        P178
# 197                     Nintendo Video is a product of        P178
# 251         Willan Nunatak belongs to the continent of         P30
# 259                            Yahoo! Tech is owned by        P127
# 403         Joseph Paul-Boncour is a native speaker of        P103
# 479                  Jean Rouch is a native speaker of        P103
# 545                      Honda Airwave is a product of        P176
# 597                             Lenta.ru is written in        P407
# 633          Andreas Carlsson holds a citizenship from         P27
# 752  European Business School Paris is headquartere...        P159
# 775         Kinji Fukasaku, who has a citizenship from         P27
# 799                      Honda EV Plus is a product of        P176
#
#     target_false_id target_true_id  target_true   target_false  \
# 8            Q29364            Q90        Paris     Montgomery
# 186          Q11463          Q2283    Microsoft          Adobe
# 197            Q248          Q8093     Nintendo          Intel
# 251             Q46            Q51   Antarctica         Europe
# 259           Q1400         Q37093        Yahoo   Pennsylvania
# 403           Q7737           Q150       French        Russian
# 479            Q652           Q150       French        Italian
# 545          Q27597          Q9584        Honda           Fiat
# 597            Q652          Q7737      Russian        Italian
# 633             Q35            Q34       Sweden        Denmark
# 752           Q5083            Q90        Paris        Seattle
# 775            Q155            Q17        Japan         Brazil
# 799           Q6686          Q9584        Honda        Renault
#
#                             subject  original_idx   split  true_prob  \
# 8              Pierre-Jean Mariette         17689  train1  24.269060
# 186         Microsoft Office Mobile         12300  train3  20.858376
# 197                  Nintendo Video         19227  train3  16.412670
# 251                  Willan Nunatak         18892  train4  21.710266
# 259                     Yahoo! Tech          9222  train4  16.264675
# 403             Joseph Paul-Boncour         11538  train5  21.068380
# 479                      Jean Rouch         19175    test  23.496683
# 545                   Honda Airwave         18118    test   8.129721
# 597                        Lenta.ru          9361    test  12.827466
# 633                Andreas Carlsson         16143    test  24.555607
# 752  European Business School Paris         12694    test  32.245594
# 775                  Kinji Fukasaku         12036    test  25.337910
# 799                   Honda EV Plus          2040    test   8.885074
#
#       max_prob    hit        pred
# 8    24.624636  False    Montreal
# 186  20.880962  False         the
# 197  16.710340  False         the
# 251  21.801659  False   Australia
# 259  17.205734  False     Verizon
# 403  21.762497  False         the
# 479  23.595036  False         the
# 545   8.258763  False         the
# 597  13.290056  False         the
# 633  24.633812  False         two
# 752  32.407665  False         the
# 775  25.431440  False         the
# 799   9.002724  False         the

# %%
original_data['hit'].mean()
# Out:
# 0.9842805320435308

# %%
original_data.to_parquet('entire_results_original.parquet')
